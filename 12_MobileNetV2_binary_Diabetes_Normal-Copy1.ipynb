# %% [markdown]
# ## MobileNetv2 Model for binary classification between Glaucoma (G) and Normal (N) classes

# %% [markdown]
# ### 00. Load libraries

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Rescaling, Activation, Dropout, Flatten, Dense, GlobalMaxPooling2D, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16,MobileNetV2,InceptionV3

import os
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# Out:
# Requirement already satisfied: tensorflow in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: packaging in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (23.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.24.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: setuptools in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.16.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\gautam\anaconda3\envs\tf2.11-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)

# %% [markdown]
# ### 01. Load images
# The images are separated into train, test and validation using the function of keras call image_dataset_from_directory

# %%
train_dir = 'Diabetes-Binary.v2i.folder/train'
test_dir = 'Diabetes-Binary.v2i.folder/test'

BATCH_SIZE = 32
IMG_HEIGHT = 264
IMG_WIDTH = 264
EPOCHS = 100

input_shape = (IMG_WIDTH, IMG_HEIGHT, 3)

# %%
# Creating generators (prepare data to feed the model)
training_generator = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='binary',
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=432,
    validation_split=0.2,
    subset='training',
).repeat(20)

validation_generator = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='binary',
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    shuffle=True,
    seed=432,
    validation_split=0.2,
    subset='validation',
).repeat(20)

test_generator = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='binary',
    shuffle=False,
    batch_size=BATCH_SIZE,
    image_size=(IMG_WIDTH, IMG_HEIGHT),
    seed=432,
)
# Out:
# Found 440 files belonging to 2 classes.
# Using 352 files for training.
# Found 440 files belonging to 2 classes.
# Using 88 files for validation.
# Found 98 files belonging to 2 classes.

# %% [markdown]
# ### 02. Model architecture
#
# Loading of pretrained VGG16 model with imagenet and creating the architecture.

# %%
pretrained = MobileNetV2(weights='imagenet', include_top=False)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 4s 0us/step

# %%
model = Sequential()

model.add(Rescaling(1./255, input_shape=input_shape))

model.add(pretrained)

model.add(Flatten())
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.5))

model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 264, 264, 3)       0
#
#  mobilenetv2_1.00_224 (Funct  (None, None, None, 1280)  2257984
#  ional)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 1)                 257
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 23,361,601
# Trainable params: 23,327,489
# Non-trainable params: 34,112
# _________________________________________________________________

# %% [markdown]
# ### 03. Weight adjustment
# As observed in the EDA, the classes were not balanced. In order for the model not to over-train, higher weights are given to those classes with fewer samples.

# %%
cat_list = os.listdir('Diabetes-Binary.v2i.folder/train/')
cat_list.sort()

lenghts = [len(os.listdir('Diabetes-Binary.v2i.folder/train/'+cat)) for cat in cat_list]
total_train_images = np.sum(lenghts)

weights = list(np.sqrt(np.round(1/(np.array(lenghts) / total_train_images),2)))

print(cat_list)
print(lenghts)
print(weights)
# Out:
# ['Diabetic', 'Normal']
# [168, 272]
# [1.6186414056238645, 1.2727922061357855]

# %% [markdown]
# ### 04. Model train
# We add earlystopping in order to keep the best model. If the model gets worse with increasing iterations, we will keep the best one.
#
# For the learning_rate, a small value (0.001) is set so that the different combinations of parameters can be correctly explored until the optimum is reached.
#
# Weights from the VGG16 model are freezed so they will not update over the training and binary crossentropy loss with Adam optimizer is used for the loss function.
#
# The number of epochs was set at 100 in order to appreciate the evolution of the model during training.

# %%
patience = 10

early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

# %%
# freeze vgg16
pretrained.trainable = False

model.compile(loss='binary_crossentropy', loss_weights=weights,
            optimizer=Adam(learning_rate=0.001),
            metrics=['accuracy'])

# %%
# Training
history = model.fit(
    training_generator,
    steps_per_epoch=10,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=10,
    verbose=1,
    callbacks = [early_stopping])
# Out:
# Epoch 1/100
# 10/10 [==============================] - 29s 2s/step - loss: 6.1553 - accuracy: 0.6344 - val_loss: 0.7446 - val_accuracy: 0.8176
# Epoch 2/100
# 10/10 [==============================] - 2s 263ms/step - loss: 0.7630 - accuracy: 0.8406 - val_loss: 0.5307 - val_accuracy: 0.8412
# Epoch 3/100
# 10/10 [==============================] - 2s 250ms/step - loss: 0.3896 - accuracy: 0.9062 - val_loss: 0.8579 - val_accuracy: 0.8716
# Epoch 4/100
# 10/10 [==============================] - 2s 244ms/step - loss: 0.1472 - accuracy: 0.9688 - val_loss: 0.5738 - val_accuracy: 0.9088
# Epoch 5/100
# 10/10 [==============================] - 3s 267ms/step - loss: 0.1274 - accuracy: 0.9656 - val_loss: 0.3929 - val_accuracy: 0.9020
# Epoch 6/100
# 10/10 [==============================] - 2s 260ms/step - loss: 0.0744 - accuracy: 0.9906 - val_loss: 0.4321 - val_accuracy: 0.9155
# Epoch 7/100
# 10/10 [==============================] - 3s 285ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 0.5127 - val_accuracy: 0.9223
# Epoch 8/100
# 10/10 [==============================] - 3s 289ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.9426
# Epoch 9/100
# 10/10 [==============================] - 3s 290ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.9722 - val_accuracy: 0.8919
# Epoch 10/100
# 10/10 [==============================] - 3s 293ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.9324
# Epoch 11/100
# 10/10 [==============================] - 2s 248ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5342 - val_accuracy: 0.9257
# Epoch 12/100
# 10/10 [==============================] - 2s 227ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5044 - val_accuracy: 0.9291
# Epoch 13/100
# 10/10 [==============================] - 2s 264ms/step - loss: 7.3299e-04 - accuracy: 1.0000 - val_loss: 0.3621 - val_accuracy: 0.9324
# Epoch 14/100
# 10/10 [==============================] - 3s 267ms/step - loss: 4.7328e-04 - accuracy: 1.0000 - val_loss: 0.4112 - val_accuracy: 0.9324
# Epoch 15/100
# 10/10 [==============================] - 3s 275ms/step - loss: 2.7878e-04 - accuracy: 1.0000 - val_loss: 0.4137 - val_accuracy: 0.9392
# Epoch 16/100
# 10/10 [==============================] - 3s 270ms/step - loss: 2.7760e-04 - accuracy: 1.0000 - val_loss: 0.4612 - val_accuracy: 0.9324
# Epoch 17/100
# 10/10 [==============================] - 3s 280ms/step - loss: 2.8328e-04 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.9257
# Epoch 18/100
# 10/10 [==============================] - 3s 275ms/step - loss: 2.6571e-04 - accuracy: 1.0000 - val_loss: 0.4455 - val_accuracy: 0.9324
# Epoch 19/100
# 10/10 [==============================] - 3s 280ms/step - loss: 2.4166e-04 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.9291
# Epoch 20/100
# 10/10 [==============================] - 3s 274ms/step - loss: 1.8651e-04 - accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.9257
# Epoch 21/100
# 10/10 [==============================] - 3s 267ms/step - loss: 1.7760e-04 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.9257
# Epoch 22/100
# 10/10 [==============================] - 2s 244ms/step - loss: 1.8167e-04 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.9358
# Epoch 23/100
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1000 batches). You may need to use the repeat() function when building your dataset.
# 10/10 [==============================] - 3s 300ms/step - loss: 1.8167e-04 - accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.9324

# %%
model.save('mobilenet_binary_diabetes_normal.h5')

# %% [markdown]
# ### 05. Analysis of results

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# The accuracy evolves positively throughout the training period resulting in values close to 1 providing a model with very good results.

# %%
# summarize history for loss
plt.plot(history.history['loss'][1:])
plt.plot(history.history['val_loss'][1:])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# In the case of loss, it is observed that as the epochs increase, their value decreases gradually until it flats, which is good for the model precision.

# %%
model = load_model('mobilenet_binary_diabetes_normal.h5')

# %%
## Predict on test data
y_pred = model.predict(test_generator)
# Out:
# 4/4 [==============================] - 3s 487ms/step

# %%
test_labels = []
for image_batch, labels_batch in test_generator:
  for vector in labels_batch:
    test_labels.append(vector.numpy().astype(int))

y_real = np.array(test_labels)

# %%
y_pred[y_pred >= 0.5] = 1
y_pred[y_pred < 0.5] = 0

# %%
cf_matrix = confusion_matrix(y_real, y_pred)
ax = sns.heatmap(cf_matrix, annot=True, fmt='d')
plt.title('Confusion Matrix Test Set')
ax.xaxis.set_ticklabels(['Diabetes','Normal'])
ax.yaxis.set_ticklabels(['Diabetes','Normal'])
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %% [markdown]
# The confusion matrix for the test set is almost perfect, only missclassifies one Cataract sample, resulting in almost 100% accuracy for both classes. This model passes the test filter and could be considered for production.

# %%
print(classification_report(y_real, y_pred, target_names=['Cataract','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#     Cataract       0.88      0.88      0.88        33
#       Normal       0.94      0.94      0.94        65
#
#     accuracy                           0.92        98
#    macro avg       0.91      0.91      0.91        98
# weighted avg       0.92      0.92      0.92        98

# %%
from PIL import Image

# %%
img=Image.open("TEST1.jpg")
img=img.resize((264,264))
print(img.size)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 img=Image.open("TEST1.jpg")
#       2 img=img.resize((264,264))
#       3 print(img.size)
#
# File ~\anaconda3\envs\tf2.11-gpu\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TEST1.jpg'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=264x264>

# %%
x=np.array(img)
prediction=model.predict(x)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 x=np.array(img)
# ----> 2 prediction=model.predict(x)
#       3 print(prediction)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_files18fka45.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\suraj\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_1" is incompatible with the layer: expected shape=(None, 264, 264, 3), found shape=(None, 264, 3)
